# %% [markdown]
# # Pandas

# %% [markdown]
# Pandas is open-source Python library which is used for data manipulation and analysis.
# It consist of data structures and functions to perform efficient operations on data. It is well-suited for working with tabular data such as spreadsheets or SQL tables.

# %%
# To install pandas
#pip install pandas

# %%
# Importing Pandas

# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '2.2.3'

# %% [markdown]
# ## Data Structures in Pandas Library
#
# Pandas provide two data structures for manipulating data which are as follows:

# %% [markdown]
# ### 1. Pandas Series
#
# A Pandas Series is one-dimensional labeled array capable of holding data of any type (integer, string, float, Python objects etc.). The axis labels are collectively called indexes.

# %% [markdown]
# ### Create first pandas series

# %%
number_series = pd.Series([2, 3, 4, 5])
print(number_series)
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# dtype: int64

# %%
number_series = pd.Series([2, 3, 4, 5], index = ['a', 'b', 'c', 'd'], name = 'Number')
print(number_series)
# Out:
# a    2
# b    3
# c    4
# d    5
# Name: Number, dtype: int64

# %% [markdown]
# ### accessing pandas series element

# %%
print(number_series['c'])  # accessing element with the help of index given by us
print(number_series[3])  # accesing element with the help of index
print(number_series.iloc[1])
# Out:
# 4
# 5
# 3
# C:\Users\91880\AppData\Local\Temp\ipykernel_13512\895083068.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(number_series[3])  # accesing element with the help of index

# %% [markdown]
# # 2. Pandas DataFrame
# Pandas DataFrame is a two-dimensional data structure with labeled axes (rows and columns).
#
# ![PandasDataframe.webp](data:image/webp;base64,...)

# %%
# creating our first DataFrame using 2-D Numpy Array

# %%
twod_array = np.random.randint(2, 10,(3,4))
twod_array
# Out:
# array([[2, 6, 8, 9],
#        [6, 3, 5, 2],
#        [9, 6, 5, 4]], dtype=int32)

# %%
twod_array = np.random.randint(2, 10,(3,4))
first_dataframe = pd.DataFrame(twod_array, columns =['Akshay', 'Devashish', 'Divy', 'Monika'], index =['a','b','c'])
first_dataframe
# Out:
#    Akshay  Devashish  Divy  Monika
# a       3          3     8       6
# b       4          4     2       4
# c       7          7     9       8

# %%
# Initialise list of lists
list_of_lists = [['Ashu', 10], ['Raghav',20], ['Shailja',30]]

# create the pandas dataframe
df = pd.DataFrame(list_of_lists, columns=['Name','Age'])

# print dataframe
df
# Out:
#       Name  Age
# 0     Ashu   10
# 1   Raghav   20
# 2  Shailja   30

# %%
# creating dataframe using Dictionary of lists(column wise) --- Dictionary of Lists must have equal-length lists:
import pandas as pd

# store the data in the dictionary
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'London', 'Paris']
}

# create dataframe
df = pd.DataFrame(data)

#print datframe
print(df)
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30    London
# 2  Charlie   35     Paris

# %% [markdown]
# # Methods of pandas for data manipulation and analysis

# %%
our_array = np.random.randn(100,5)
our_array
# Out:
# array([[-1.24489341e-01, -2.02179799e+00, -2.70777934e-01,
#          1.17159677e+00,  5.30634535e-01],
#        [-4.77946560e-01, -1.08254402e-01, -9.88076970e-01,
#          6.65639441e-01,  7.04955948e-01],
#        [ 1.14578445e+00,  3.70325308e-01, -6.25844418e-01,
#         -1.89382591e+00, -2.23069155e+00],
#        [-1.00587005e+00, -4.23197570e-01,  9.38424541e-01,
#         -1.50477860e+00,  1.73050339e-01],
#        [-1.14023314e+00, -5.65317033e-01,  1.36936767e-01,
#         -9.76183233e-01,  1.12601797e+00],
#        [ 8.05516051e-01,  1.07318423e+00, -7.06440120e-01,
#         -3.36526197e-01,  6.28075560e-02],
#        [-1.24809257e+00,  7.55643532e-01,  2.36134934e-01,
#          3.94162533e-01, -4.11285801e-01],
#        [-1.91625845e-01,  1.23458532e+00,  2.85707329e-01,
#         -4.01528286e-01,  2.36275597e+00],
#        [ 6.32299693e-01,  9.91539859e-01, -6.37640832e-01,
#          5.16964397e-01,  5.13413376e-01],
# ...

# %%
import numpy as np
import pandas as pd

our_array = np.random.randn(100,5)
df = pd.DataFrame(our_array, columns = ['A', 'B', 'C', 'D', 'E'])
df
# Out:
#            A         B         C         D         E
# 0   1.431881  0.532178 -0.363303 -1.661186  0.033682
# 1  -0.402145 -0.641325 -0.210687  0.699959 -0.604058
# 2   0.295977 -0.374869 -1.822413 -0.550956 -1.071865
# 3  -0.576437 -0.811250  0.974888 -0.435470 -0.725578
# 4  -0.040426  0.574809  0.000565 -0.201163  0.309197
# ..       ...       ...       ...       ...       ...
# 95 -0.277405  0.117368  1.257312  0.740777  1.486476
# 96 -0.562853  0.330775 -0.117912  1.229922 -1.843268
# 97  0.099872 -0.407516  1.182059 -0.524704  0.981179
# 98  1.560868 -0.785067 -3.665755  0.827674 -0.500284
# 99 -0.745203  0.389314 -1.213565  2.271936 -1.306410
#
# [100 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       100 non-null    float64
#  1   B       100 non-null    float64
#  2   C       100 non-null    float64
#  3   D       100 non-null    float64
#  4   E       100 non-null    float64
# dtypes: float64(5)
# memory usage: 4.0 KB

# %%
df.describe()  #Statistical summary
# Out:
#                 A           B           C           D           E
# count  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     0.088571   -0.007571    0.219501    0.068031   -0.202492
# std      0.947446    0.781043    1.009636    0.975418    1.025287
# min     -2.060763   -1.882807   -3.665755   -2.541319   -2.267825
# 25%     -0.566249   -0.580815   -0.470892   -0.528126   -1.061951
# 50%     -0.030353   -0.020641    0.220133   -0.008092   -0.251054
# 75%      0.748305    0.514983    0.977475    0.728340    0.657023
# max      2.419772    1.802128    2.621482    2.672828    2.388957

# %%
df.head() #  by default it prints 5 values
df.head(14)
# Out:
#            A         B         C         D         E
# 0   1.431881  0.532178 -0.363303 -1.661186  0.033682
# 1  -0.402145 -0.641325 -0.210687  0.699959 -0.604058
# 2   0.295977 -0.374869 -1.822413 -0.550956 -1.071865
# 3  -0.576437 -0.811250  0.974888 -0.435470 -0.725578
# 4  -0.040426  0.574809  0.000565 -0.201163  0.309197
# 5   0.391416 -0.846126  1.822586  1.617757  0.810515
# 6  -0.791211 -0.730367  2.115742  0.898632 -1.671895
# 7  -0.232403 -0.580766  0.196348 -0.675593  0.713242
# 8  -0.274567 -0.343135 -1.272406 -1.598042 -1.229815
# 9   0.280893 -0.285547  0.017359 -0.286196 -1.439689
# 10  1.301085  0.214045  0.358605  0.342441  0.338724
# 11 -0.991443 -0.212527 -1.025623 -0.663377 -0.091549
# 12 -0.789832  1.034817  0.849165  1.680535  0.249179
# 13  1.528832  1.066888 -0.325732  0.880777 -0.253991

# %%
df.tail()  # by default it prints 5 values
df.tail(15)
# Out:
#            A         B         C         D         E
# 85  1.165689 -0.392672 -0.381672 -0.130786 -0.209728
# 86 -0.816065 -0.826278 -0.412245 -0.538394  1.715297
# 87  0.494238 -0.178063  1.081667 -0.618253  0.833140
# 88 -0.039404  0.661559 -0.342178  0.951827  0.203711
# 89 -0.021303 -0.054374 -0.446370  0.498382 -0.432172
# 90  0.351626 -0.766530 -0.624959 -2.541319  1.624317
# 91 -0.951252 -0.052268  0.531741  0.026210 -1.058647
# 92  1.796451 -1.258974 -1.778619 -1.103819 -0.301192
# 93 -0.305970  0.008896  0.142915  0.300861  1.432547
# 94 -0.826490 -0.067755  0.083725 -1.053724 -0.553878
# 95 -0.277405  0.117368  1.257312  0.740777  1.486476
# 96 -0.562853  0.330775 -0.117912  1.229922 -1.843268
# 97  0.099872 -0.407516  1.182059 -0.524704  0.981179
# 98  1.560868 -0.785067 -3.665755  0.827674 -0.500284
# 99 -0.745203  0.389314 -1.213565  2.271936 -1.306410

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
df.rename(columns = {'A': "Column1", "E":"Column5"})
# Out:
#      Column1         B         C         D   Column5
# 0   1.431881  0.532178 -0.363303 -1.661186  0.033682
# 1  -0.402145 -0.641325 -0.210687  0.699959 -0.604058
# 2   0.295977 -0.374869 -1.822413 -0.550956 -1.071865
# 3  -0.576437 -0.811250  0.974888 -0.435470 -0.725578
# 4  -0.040426  0.574809  0.000565 -0.201163  0.309197
# ..       ...       ...       ...       ...       ...
# 95 -0.277405  0.117368  1.257312  0.740777  1.486476
# 96 -0.562853  0.330775 -0.117912  1.229922 -1.843268
# 97  0.099872 -0.407516  1.182059 -0.524704  0.981179
# 98  1.560868 -0.785067 -3.665755  0.827674 -0.500284
# 99 -0.745203  0.389314 -1.213565  2.271936 -1.306410
#
# [100 rows x 5 columns]

# %%
df
# Out:
#            A         B         C         D         E
# 0   1.431881  0.532178 -0.363303 -1.661186  0.033682
# 1  -0.402145 -0.641325 -0.210687  0.699959 -0.604058
# 2   0.295977 -0.374869 -1.822413 -0.550956 -1.071865
# 3  -0.576437 -0.811250  0.974888 -0.435470 -0.725578
# 4  -0.040426  0.574809  0.000565 -0.201163  0.309197
# ..       ...       ...       ...       ...       ...
# 95 -0.277405  0.117368  1.257312  0.740777  1.486476
# 96 -0.562853  0.330775 -0.117912  1.229922 -1.843268
# 97  0.099872 -0.407516  1.182059 -0.524704  0.981179
# 98  1.560868 -0.785067 -3.665755  0.827674 -0.500284
# 99 -0.745203  0.389314 -1.213565  2.271936 -1.306410
#
# [100 rows x 5 columns]

# %%
df.rename(columns = {'A': "Column1", "E":"Column5"}, inplace = True)

# %%
df
# Out:
#      Column1         B         C         D   Column5
# 0   1.431881  0.532178 -0.363303 -1.661186  0.033682
# 1  -0.402145 -0.641325 -0.210687  0.699959 -0.604058
# 2   0.295977 -0.374869 -1.822413 -0.550956 -1.071865
# 3  -0.576437 -0.811250  0.974888 -0.435470 -0.725578
# 4  -0.040426  0.574809  0.000565 -0.201163  0.309197
# ..       ...       ...       ...       ...       ...
# 95 -0.277405  0.117368  1.257312  0.740777  1.486476
# 96 -0.562853  0.330775 -0.117912  1.229922 -1.843268
# 97  0.099872 -0.407516  1.182059 -0.524704  0.981179
# 98  1.560868 -0.785067 -3.665755  0.827674 -0.500284
# 99 -0.745203  0.389314 -1.213565  2.271936 -1.306410
#
# [100 rows x 5 columns]

# %% [markdown]
# # Loading a csv file

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("Iris.csv")
#df = pd.read_csv("C:/Users/Dell/JupyterPythoncodes/Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df['Species']
#df.Species
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df['PetalLengthCm'].unique()
# Out:
# array([1.4, 1.3, 1.5, 1.7, 1.6, 1.1, 1.2, 1. , 1.9, 4.7, 4.5, 4.9, 4. ,
#        4.6, 3.3, 3.9, 3.5, 4.2, 3.6, 4.4, 4.1, 4.8, 4.3, 5. , 3.8, 3.7,
#        5.1, 3. , 6. , 5.9, 5.6, 5.8, 6.6, 6.3, 6.1, 5.3, 5.5, 6.7, 6.9,
#        5.7, 6.4, 5.4, 5.2])

# %%
df['PetalLengthCm'].nunique()
# Out:
# 43

# %%
df["SepalLengthCm"].unique()
# Out:
# array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.4, 4.8, 4.3, 5.8, 5.7, 5.2, 5.5,
#        4.5, 5.3, 7. , 6.4, 6.9, 6.5, 6.3, 6.6, 5.9, 6. , 6.1, 5.6, 6.7,
#        6.2, 6.8, 7.1, 7.6, 7.3, 7.2, 7.7, 7.4, 7.9])

# %%
dir(df["SepalLengthCm"])
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__column_consortium_standard__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__firstlineno__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
df[["SepalLengthCm","SepalWidthCm","PetalLengthCm"]]
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm
# 0              5.1           3.5            1.4
# 1              4.9           3.0            1.4
# 2              4.7           3.2            1.3
# 3              4.6           3.1            1.5
# 4              5.0           3.6            1.4
# ..             ...           ...            ...
# 145            6.7           3.0            5.2
# 146            6.3           2.5            5.0
# 147            6.5           3.0            5.2
# 148            6.2           3.4            5.4
# 149            5.9           3.0            5.1
#
# [150 rows x 3 columns]

# %%
df["Species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df["Species"].nunique()
# Out:
# 3

# %%
# I only want to see the "setosa" records from the dataset(filter)

df[df['Species'] == "Iris-setosa"]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
# sepal_length >=5 --df
df[df['SepalLengthCm'] >= 5]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 7      8            5.0           3.4            1.5           0.2
# 10    11            5.4           3.7            1.5           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 4       Iris-setosa
# 5       Iris-setosa
# 7       Iris-setosa
# 10      Iris-setosa
# ..              ...
# ...

# %%
df[df['SepalLengthCm'] >= 5].min()
df[df['SepalLengthCm'] >= 5].max()
# Out:
# Id                          150
# SepalLengthCm               7.9
# SepalWidthCm                4.4
# PetalLengthCm               6.9
# PetalWidthCm                2.5
# Species          Iris-virginica
# dtype: object

# %%
df[df['PetalWidthCm'] == 0.4]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 15  16            5.7           4.4            1.5           0.4  Iris-setosa
# 16  17            5.4           3.9            1.3           0.4  Iris-setosa
# 21  22            5.1           3.7            1.5           0.4  Iris-setosa
# 26  27            5.0           3.4            1.6           0.4  Iris-setosa
# 31  32            5.4           3.4            1.5           0.4  Iris-setosa
# 44  45            5.1           3.8            1.9           0.4  Iris-setosa

# %%
len(df[df['PetalWidthCm'] == 0.4])
# Out:
# 7

# %%
# EDA -- Exploratory data analysis

# %%
df[(df['Species'] == "Iris-setosa") & (df["SepalWidthCm"] >= 3.9)]  #can also use and
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 14  15            5.8           4.0            1.2           0.2  Iris-setosa
# 15  16            5.7           4.4            1.5           0.4  Iris-setosa
# 16  17            5.4           3.9            1.3           0.4  Iris-setosa
# 32  33            5.2           4.1            1.5           0.1  Iris-setosa
# 33  34            5.5           4.2            1.4           0.2  Iris-setosa

# %%
# HomeWork

# %% [markdown]
# # Home Work
#
# Download any dataset from Kaggle that consumes less memory, use all methods discused in today's session, create a small documentation(use markdown or raw text) of what you understand with the dataset.
